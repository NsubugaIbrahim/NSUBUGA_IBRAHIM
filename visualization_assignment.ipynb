# %%
#Data Preprocessing or Data Cleaning
#Bad data handling
#1.empty values
#2.wrong formats    30/03/03     300303    30-03-03
#3.wrong data     Age 23    -23  123
#4.duplicates    more entries from the same person
import pandas as pd
import numpy as np
import matplotlib as plt
df = pd.read_csv('data.csv')
#check for empty cells
print(df.isnull().sum())

#check wrong formats
print(df.dtypes)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#wrong data
#check for negative values in numeric columns
for col in df.select_dtypes(include=[np.number]).columns:
    if (df[col] < 0).any():
        print(f"Negative values found in column: {col}")

# %%
#Duplicates
duplicates = df.duplicated()
if duplicates.any():
    print("Duplicates found:")
    print(df[duplicates])
# Out:
# Duplicates found:
#      Duration  Pulse  Maxpulse  Calories
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 71         60    109       153     387.6
# 113        45    100       120     225.3
# 155        60    111       151     368.5

# %%
#recommendations
#1. convert to correct format
#2. fill empty values with mean for numeric values
#3. remove duplicates in rows not in columns
#4. correct wrong data

#EDA Exploratory Data Analysis
#check the shape of the data
print("Shape of the data:", df.shape)
# Out:
# Shape of the data: (169, 4)

# %%
#fill empty values with mean for numeric columns
for col in ['Duration', 'Pulse','Maxpulse', 'Calories']:
    df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15948\1071028059.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
df.head(30)
# Out:
#     Duration  Pulse  Maxpulse    Calories
# 0         60    110       130  409.100000
# 1         60    117       145  479.000000
# 2         60    103       135  340.000000
# 3         45    109       175  282.400000
# 4         45    117       148  406.000000
# 5         60    102       127  300.000000
# 6         60    110       136  374.000000
# 7         45    104       134  253.300000
# 8         30    109       133  195.100000
# 9         60     98       124  269.000000
# 10        60    103       147  329.300000
# 11        60    100       120  250.700000
# 12        60    106       128  345.300000
# 13        60    104       132  379.300000
# 14        60     98       123  275.000000
# 15        60     98       120  215.200000
# 16        60    100       120  300.000000
# 17        45     90       112  375.790244
# 18        60    103       123  323.000000
# 19        45     97       125  243.000000
# 20        60    108       131  364.200000
# ...

# %%
#for empty cells
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#check the shape of the dataset
print("Shape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (169, 4)

# %%
#Summary statistics
print("Summary statistics:")
df.describe()
# Out:
# Summary statistics:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   169.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   262.385991
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   253.300000
# 50%     60.000000  105.000000  131.000000   321.000000
# 75%     60.000000  111.000000  141.000000   384.000000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#Data visualization......Quickest way to make sense out of data
#Libraries used for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram of 'Duration'
# Set up the figure size
plt.figure(figsize=(15, 10))

# Histogram of 'Duration'
plt.subplot(2, 2, 1)
sns.histplot(df['Duration'], bins=30, kde=True)
plt.title('Duration Distribution')
# Histogram of 'Pulse'
plt.subplot(2, 2, 2)
sns.histplot(df['Pulse'], bins=30, kde=True)
plt.title('Pulse Distribution')

# Exercise Plot for Maxpulse and Colories for Histrogram
# Out:
# Text(0.5, 1.0, 'Pulse Distribution')

# %%
# Scatter plot of 'Duration' vs 'Pulse'
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
sns.scatterplot(x='Duration', y='Pulse', data=df)
plt.title('Duration vs Pulse')
# Scatter plot of 'Pulse'
plt.subplot(2, 2, 2)
sns.scatterplot(x='Pulse', y='Calories', data=df)
plt.title('Pulse vs Calories')
# Out:
# Text(0.5, 1.0, 'Pulse vs Calories')

# %%
# Correlation heatmap
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Figure size
plt.figure(figsize=(15, 10))

#Histogram of 'Maxpulse'
plt.subplot(2, 2, 1)
sns.histplot(df['Maxpulse'], bins=30, kde=True)
plt.title('Maxpulse Distribution')

# Histogram of 'Calories'
plt.subplot(2, 2, 2)        
sns.histplot(df['Calories'], bins=30, kde=True)
plt.title('Calories Distribution')
# Out:
# Text(0.5, 1.0, 'Calories Distribution')
